# %% [markdown]
# cufflinks - https://github.com/santosjorge/cufflinks
# plotly - https://plotly.com/python/plotly-express/
# seaborn - https://seaborn.pydata.org/index.html
# matplotlib - https://matplotlib.org/stable/index.html

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#loading a sns data,it's available inside seaborn library
df=sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#default it will plot line graph
#it will plot only numerical columns
# without using df.describe() ,still we can say something about data
# we can say the variance also ,like which has more variance
#petal length variation is more
df.plot()
# Out:
# <AxesSubplot:>

# %%
#from describe also by seeing min and max value we can say variation is more in petal_length
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#kind means which type of graph we want
#here alpha=dfine colour
df.plot(kind='area' , alpha=0.9)
# Out:
# <AxesSubplot:>

# %%
# stack means I want to plot the data with normal scale
df.plot(kind='area' , alpha=0.9 , stacked=False)
# Out:
# <AxesSubplot:>

# %%
# there is no relation betn two column
df.plot.scatter(x='sepal_length',y='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
#here we can made the decision that if sepa_length is increasing then petal_length is also increasing
df.plot.scatter(x='sepal_length',y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
#c means color we are using here for sepal_width
#darker is the colour more is the sepal_width
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
#s is used to fix the size of the bubble 
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
#in size instead of direct no. we can give col.name also
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=df['sepal_length']*20)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
#for hexbin we have to give gridsize instead of s
df.plot.hexbin(x='sepal_length',y='petal_length',gridsize=10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
# cmap for colourmap is used to create a fancy graph
df.plot.hexbin(x='sepal_length',y='petal_length',gridsize=10,cmap='viridis')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
# for plotting 3D graph
# without this we can't plot any 3D graph
from mpl_toolkits import mplot3d

# %%
# it will generate 30 data in betwn range of -1 to 6 and that would be my x axis
x=np.linspace(-1,6,30)
x
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
# it will generate 30 data in betwn range of -1 to 6 and that would be my y axis
y=np.linspace(-1,6,30)
y
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
#we need x axis to prepare 3d graph
z=x+y

# %%
z
# Out:
# array([-2.        , -1.51724138, -1.03448276, -0.55172414, -0.06896552,
#         0.4137931 ,  0.89655172,  1.37931034,  1.86206897,  2.34482759,
#         2.82758621,  3.31034483,  3.79310345,  4.27586207,  4.75862069,
#         5.24137931,  5.72413793,  6.20689655,  6.68965517,  7.17241379,
#         7.65517241,  8.13793103,  8.62068966,  9.10344828,  9.5862069 ,
#        10.06896552, 10.55172414, 11.03448276, 11.51724138, 12.        ])

# %%
#white colour box iscreated by (projection = "3d")
#for setting the label of x,y and z
ax=plt.axes(projection='3d')
ax.plot3D(x,y,z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
#here we are trying to create 3d graph for iris data set
ax=plt.axes(projection='3d')
ax.plot3D(df['sepal_length'],df['sepal_width'],df['petal_length'])
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
ax.set_zlabel('petal_length')
# Out:
# Text(0.5, 0, 'petal_length')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#using fig size we can increase the graph size
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
#using iloc we can extract particular part of a data set
df.iloc[5:11]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %% [markdown]
# # Bar Graph

# %%
df.plot(kind ="bar")
# Out:
# <AxesSubplot:>

# %%
df.plot(kind ="bar",figsize=(20,10))
# fixing the size
# Out:
# <AxesSubplot:>

# %%
#by taking only a part of dataset we can also plot bar graph and fixsize also
df.iloc[5:11].plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
#barh=horizontal bar
df.iloc[5:11].plot(kind='barh',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Histogram

# %%
#to plot histogram
# it will help to understand the range and frequencies
# x is for range and y axis for frequeny(how many counts or datapoints we have)
# its like groupby operation

df.plot(kind='hist',figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# for one particular column
df['sepal_length'].plot(kind='hist',figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#aplha is used for colour density
#g stands for green colour
df.hist(figsize=(20,10), color='g',alpha=.9)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
#we can give direct color code also
df.hist(figsize=(20,10), color='#ffff33',alpha=.9)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
# graph inside cufflink will be interactive 
# without cufflinks we can't do df.iplot()
# iplot is from ploty and cufflinks
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#default is line graph
df.iplot()
# Out:
# <div>                            <div id="866adb14-a813-4363-8110-c465e93b49e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length',y='sepal_width',kind='scatter')
# Out:
# <div>                            <div id="23cf1f25-d0eb-46d5-ab30-b662dda724c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#to make scatter plot use mode
df.iplot(x='sepal_length',y='sepal_width',kind='scatter',mode='markers')
# Out:
# <div>                            <div id="cce74148-e780-4bae-8fb6-3f48f2c1b88a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#bubble graph
#size is varying according to sepal_length
df.iplot(x='sepal_length',y='sepal_width',size='sepal_length',kind='bubble')
# Out:
# <div>                            <div id="e0827a32-1150-4ef9-82c2-8d785e7a505d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#3d bubble(mention 3 axes)
df.iplot(x='sepal_length',y='sepal_width',z='petal_length',size='sepal_length',kind='bubble3d')
# Out:
# <div>                            <div id="85a70dfb-ab95-4ba1-a069-fae1c4d77064" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#load tips dataset from seaborn library
df1=sns.load_dataset('tips')
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#when bill is high then tip is also high
df1.plot(x='total_bill',y='tip',kind='scatter')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#did ame comparision using iplot
df1.iplot(x='total_bill',y='tip',kind='scatter',mode='markers')
# Out:
# <div>                            <div id="0113c33a-8f83-4108-97f4-2871fb5fcbc2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # SEABORN

# %%
# smoker person gives the highest tips
#hue is used here like a group by statement
sns.relplot(x='total_bill',y='tip',data=df1,hue='smoker')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#value_counts is like groupby
df1['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
#smoker who came for dinner gave highest tip
sns.relplot(x='total_bill',y='tip',data=df1,hue='time',style='smoker')

# %%
#male person who came for dinner gave the highest tip
sns.relplot(x='total_bill',y='tip',data=df1,hue='time',style='sex')

# %%
#we can give hue and style as a same parameter
sns.relplot(x='total_bill',y='tip',data=df1,hue='size',style='size')

# %%
#majority of people are coming for dinner 
#col gives us two different graph here
sns.relplot(x='total_bill',y='tip',data=df1,col='time')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#from iris data we can compare 3 species also 
sns.relplot(x='sepal_length',y='sepal_width',data=df,col='species')

# %%
# majority of people are coming on saturday and sunday
sns.relplot(x='total_bill',y='tip',data=df1,col='day')

# %%
# for categorical data
# on saturday we get highest bill
sns.catplot(x='day',y='total_bill',data=df1)

# %%
#on digonal all histograms are there
#we can do our own analysis by taking any of two measure
sns.pairplot(df1)

# %%
#iris dataset
sns.pairplot(df)

# %%
#in Plotly


df.scatter_matrix()
# Out:
# <div>                            <div id="55dd86dc-05f2-4351-9697-193acfc710e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.jointplot(x=df1.total_bill,y=df1.tip)

# %%
sns.jointplot(x=df1.total_bill,y=df1.tip,kind='hex')

# %%
sns.pairplot(df1)
sns.set(rc={'figure.figsize':(20,10)})

# %%
sns.regplot(x=df1.total_bill,y=df1.tip)
sns.set(rc={'figure.figsize':(20,10)})

# %% [markdown]
# # code from official documentation webside

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Load the example car crash dataset
crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="total", y="abbrev", data=crashes,
            label="Total", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="alcohol", y="abbrev", data=crashes,
            label="Alcohol-involved", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="upper left", frameon=True)
ax.set(xlim=(0, 24), ylabel="country",xlabel="Automobile collisions per billion miles")
sns.despine(left=True, bottom=True)

# %%
sns.load_dataset("car_crashes")
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import plotly.express as px

fig = px.scatter(df1, x="total_bill", y="tip", color="time")
fig.show()
# Out:
# <div>                            <div id="03c643e9-1f26-4455-8cf7-0a197f802714" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03c643e9-1f26-4455-8cf7-0a197f802714")) {                    Plotly.newPlot(                        "03c643e9-1f26-4455-8cf7-0a197f802714",                        [{"hovertemplate":"time=Dinner<br>total_bill=%{x}<br>tip=%{y}<extra></extra>","legendgroup":"Dinner","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Dinner","orientation":"v","showlegend":true,"x":[16.99,10.34,21.01,23.68,24.59,25.29,8.77,26.88,15.04,14.78,10.27,35.26,15.42,18.43,14.83,21.58,10.33,16.29,16.97,20.65,17.92,20.29,15.77,39.42,19.82,17.81,13.37,12.69,21.7,19.65,9.55,18.35,15.06,20.69,17.78,24.06,16.31,16.93,18.69,31.27,16.04,17.
# ...

# %%
import plotly.express as px

fig = px.bar(df1, x="sex", y="total_bill", color="smoker", barmode="group")
fig.show()
# Out:
# <div>                            <div id="b55139a9-6a05-477f-9a10-cfc5fb236994" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b55139a9-6a05-477f-9a10-cfc5fb236994")) {                    Plotly.newPlot(                        "b55139a9-6a05-477f-9a10-cfc5fb236994",                        [{"alignmentgroup":"True","hovertemplate":"smoker=No<br>sex=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Female","Male","Female","Male","Female","Male","Male","Female","Female","Male","Male","Male","Male
# ...

# %%
cufflinks - https://github.com/santosjorge/cufflinks
plotly - https://plotly.com/python/plotly-express/
seaborn - https://seaborn.pydata.org/index.html
matplotlib - https://matplotlib.org/stable/index.html
