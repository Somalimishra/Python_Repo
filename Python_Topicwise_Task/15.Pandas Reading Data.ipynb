# %% [markdown]
# ->Pandas Library is used for Data Manipulation/Aggregation purposes.
# ->DATA- Understand, Clean, Prepare, Subset, Summarize, Analyze
# To work on the above steps we need to have the methods handy.For this we need to learn pandas.
# ->Dataset Link: https://drive.google.com/drive/folders/1vdLTTFQczfXW5o__f1ce5WfDqfI5JYAF?usp=sharing

# %%
#Importing Pandas Library
import pandas as pd

# %% [markdown]
# # Different ways of reading the data

# %%
#Reading excel data file from local and storing it in df dataframe
#here converted backward slash to forward slash with file extension to fetch the data
df=pd.read_excel('D:/1.SOMALI MISHRA/1.iNeuron/Python/Data set/pandas dataset/Attribute DataSet.xlsx')

# %%
#printing df data frame
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
#another way to fetch the data from local drive by writing 'r' just before the path
pd.read_excel(r'D:\1.SOMALI MISHRA\1.iNeuron\Python\Data set\pandas dataset\Attribute DataSet.xlsx')
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
#another way to fetch the data by writing the file and extension
#As I have uploaded the file in jupyter notebook itself,i can able to access the data directly
pd.read_excel('Attribute DataSet.xlsx')
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
#another way to fetch the data by writing the file and extension with double backward slash
pd.read_excel('D:\\1.SOMALI MISHRA\\1.iNeuron\\Python\\Data set\\pandas dataset\\Attribute DataSet.xlsx')
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %% [markdown]
# -In Pandas, tabular form of data is called DataFrame.

# %%
#check the data type of df and it is data frame type
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#it will give 1st 5 records from df data frame
df.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
#it will give 1st 3 records from df data frame
df.head(3)
# Out:
#      Dress_ID    Style Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy   Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual   Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage  High     0.0    L  Automn   o-neck         full
#
#   waiseline    Material FabricType Decoration Pattern Type  Recommendation
# 0    empire         NaN    chiffon    ruffles       animal               1
# 1   natural  microfiber        NaN    ruffles       animal               0
# 2   natural    polyster        NaN        NaN        print               0

# %%
#it will give last 2 records from df data frame
df.tail(2)
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline Material  FabricType Decoration Pattern Type  Recommendation
# 498    empire     silk  broadcloth   applique        print               1
# 499    empire   cotton    Corduroy       lace        solid               0

# %%
#it will give last 5 records from df data frame
df.tail()
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
#Reading data from different sheet of same excel workbook i.e sheet2
pd.read_excel('D:/1.SOMALI MISHRA/1.iNeuron/Python/Data set/pandas dataset/Attribute DataSet.xlsx',sheet_name='Sheet2')
# Out:
#     rjhtj  kngijr  kgmgorjo  jnfkgjn  nrjg
# 0   rjhtj  kngijr  kgmgorjo  jnfkgjn  nrjg
# 1   rjhtj  kngijr  kgmgorjo  jnfkgjn  nrjg
# 2   rjhtj  kngijr  kgmgorjo  jnfkgjn  nrjg
# 3       0       0         0        0     0
# 4       0       0         0        0     0
# 5       0       0         0        0     0
# 6       0       0         0        0     0
# 7   rjhtj  kngijr  kgmgorjo  jnfkgjn  nrjg
# 8   rjhtj  kngijr  kgmgorjo  jnfkgjn  nrjg
# 9   rjhtj  kngijr  kgmgorjo  jnfkgjn  nrjg
# 10  rjhtj  kngijr  kgmgorjo  jnfkgjn  nrjg
# 11  rjhtj  kngijr  kgmgorjo  jnfkgjn  nrjg

# %%
#reading data from excel sheet and taking header as None(as we dont want the 1st record to be as header)
#we can give our own header name/column name by writing name and passing list of names through a list
#header=None
#names=['A','B','C','D','E','F','G','H']
pd.read_excel('D:/1.SOMALI MISHRA/1.iNeuron/Python/Data set/pandas dataset/Attribute DataSet.xlsx',sheet_name='Sheet3',header=None,names=['A','B','C','D','E','F','G','H'])
# Out:
#       A    B    C    D    E    F    G   H
# 0   687  615  231  490  849  283  516 NaN
# 1   924  396  919  919  754  353  102 NaN
# 2   205   86  557  343  793  880  958 NaN
# 3   349  674  578  574  707  475  506 NaN
# 4   620   63  745  658  893  591  829 NaN
# 5   445  194  181  768  975  378  432 NaN
# 6   205   71  170  430  583  953  398 NaN
# 7   350  153  782  554  778  517  837 NaN
# 8   106  821  656  522  232  213  881 NaN
# 9   312   61  545   71  650  901  391 NaN
# 10  988  886  449  412  897  991  841 NaN
# 11  300  879  821  483   44  336   86 NaN
# 12  686  763  583  845  416  924  137 NaN
# 13  740  855  132  778  617  974  679 NaN
# 14  878  312  238   32   77   83  170 NaN

# %%
#Reading another excel data set from local
pd.read_excel('D:\\1.SOMALI MISHRA\\1.iNeuron\\Python\\Data set\\pandas dataset\\Dress Sales.xlsx')
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
#Reading csv(Comma Separated Values) file from local and by defining our own header name
#header=None
#names=["Age","Patient's year of operation","Number of positive","Survival status"]
pd.read_csv('D:\\1.SOMALI MISHRA\\1.iNeuron\\Python\\Data set\\pandas dataset\\haberman.csv',header=None,names=["Age","Patient's year of operation","Number of positive","Survival status"])
# Out:
#      Age  Patient's year of operation  Number of positive  Survival status
# 0     30                           64                   1                1
# 1     30                           62                   3                1
# 2     30                           65                   0                1
# 3     31                           59                   2                1
# 4     31                           65                   4                1
# ..   ...                          ...                 ...              ...
# 301   75                           62                   1                1
# 302   76                           67                   0                1
# 303   77                           65                   3                1
# 304   78                           65                   1                2
# 305   83                           58                   2                2
#
# [306 rows x 4 columns]

# %%
#reading another csv file with other delimiter
pd.read_csv('D:\\1.SOMALI MISHRA\\1.iNeuron\\Python\\Data set\\pandas dataset\\haberman - @.csv')
# Out:
#       30@64@1@1
# 0     30@62@3@1
# 1     30@65@0@1
# 2     31@59@2@1
# 3     31@65@4@1
# 4    33@58@10@1
# ..          ...
# 300   75@62@1@1
# 301   76@67@0@1
# 302   77@65@3@1
# 303   78@65@1@2
# 304   83@58@2@2
#
# [305 rows x 1 columns]

# %%
#reading csv file and by giving separator as '@' we can read the file in proper format
pd.read_csv('D:\\1.SOMALI MISHRA\\1.iNeuron\\Python\\Data set\\pandas dataset\\haberman - @.csv',sep='@')
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
#reading text file separated with commas
pd.read_table(r'D:\1.SOMALI MISHRA\1.iNeuron\Python\Data set\pandas dataset\Sports_comma.txt')
# Out:
#   Team,Score
# 0       A,50
# 1       B,30
# 2      C,100
# 3       D,58
# 4       E,92

# %%
#reading comma separated text file in a proper format by giving sep=','
pd.read_table(r'D:\1.SOMALI MISHRA\1.iNeuron\Python\Data set\pandas dataset\Sports_comma.txt',sep=',')
# Out:
#   Team  Score
# 0    A     50
# 1    B     30
# 2    C    100
# 3    D     58
# 4    E     92

# %%
#Reading csv file from github
#first serach in google github csv file
#then Go to Raw option and then get the link. 
#This raw option will not be available for every type of format
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv')
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# ...    ...    ...    ...    ...    ...    ...      ...    ...       ...
# 1245  2005  0.422  0.252 -0.024 -0.584 -0.285  1.88850  0.043        Up
# 1246  2005  0.043  0.422  0.252 -0.024 -0.584  1.28581 -0.955      Down
# 1247  2005 -0.955  0.043  0.422  0.252 -0.024  1.54047  0.130        Up
# 1248  2005  0.130 -0.955  0.043  0.422  0.252  1.42236 -0.298      Down
# 1249  2005 -0.298  0.130 -0.955  0.043  0.422  1.38254 -0.489      Down
#
# [1250 rows x 9 columns]

# %%
#reading another csv file from github
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BCF.csv')
# Out:
#            date  values.I2P  values.P2I  values.JPI
# 0    1996-04-01   -2.580556   -0.836444        63.3
# 1    1996-05-01   -2.882258   -1.972581        66.3
# 2    1996-06-01   -1.742778   -0.478778        59.7
# 3    1996-07-01   -0.397796   -1.574301        63.3
# 4    1996-08-01   -0.977151   -1.797312        63.8
# ..          ...         ...         ...         ...
# 112  2005-08-01   -2.144935   -1.646989        49.0
# 113  2005-09-01   -3.543270   -1.769889        49.9
# 114  2005-10-01   -4.500484   -2.309946        50.6
# 115  2005-11-01   -4.098556   -1.528611        57.4
# 116  2005-12-01   -5.797043   -2.872849        52.9
#
# [117 rows x 4 columns]

# %%
#Extracting Tabular Data from website: https://www.basketball-reference.com/leagues/NBA_2015_totals.html and storing it in 'a'
a=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
a
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
#checking data types of html file which is list
type(a)
# Out:
# list

# %%
#This tells us the number of tables present in the list a. 
#here we have one table so returns 1
len(a)
# Out:
# 1

# %%
#Accessing data from list a
#this is the actual data
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
#Reading json (Java Script Object Notation) format: It is a Combination of Dictionaries: 
#We can use json viewer online (in google search for json viewer)to understand json in a better way
#Keys will be treated as column Names and Row will be our values of those keys in json format 
js=pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')
js
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app', 'state_reason'],
#       dtype='object')

# %%
#in user column so many dictionaries are there
js['user']
# Out:
# 0     {'login': 'bherwerth', 'id': 108834862, 'node_...
# 1     {'login': 'Zeroto521', 'id': 25895405, 'node_i...
# 2     {'login': 'StefRe', 'id': 19879328, 'node_id':...
# 3     {'login': 'windowshopr', 'id': 40477419, 'node...
# 4     {'login': 'bzhaoopenstack', 'id': 11386522, 'n...
# 5     {'login': 'PriestlyAdejo', 'id': 108146732, 'n...
# 6     {'login': 'PriestlyAdejo', 'id': 108146732, 'n...
# 7     {'login': 'GivyBoy', 'id': 58392771, 'node_id'...
# 8     {'login': 'mattB1989', 'id': 13086632, 'node_i...
# 9     {'login': 'bherwerth', 'id': 108834862, 'node_...
# 10    {'login': 'ravindrabajpai', 'id': 1445512, 'no...
# 11    {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 12    {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 13    {'login': 'shourya5', 'id': 73142986, 'node_id...
# 14    {'login': 'adrienpacifico', 'id': 6614121, 'no...
# 15    {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 16    {'login': 'attack68', 'id': 24256554, 'node_id...
# ...

# %%
#Unwrapping dictionary of dictionary
js['user'][0]
# Out:
# {'login': 'bherwerth',
#  'id': 108834862,
#  'node_id': 'U_kgDOBnywLg',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/108834862?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/bherwerth',
#  'html_url': 'https://github.com/bherwerth',
#  'followers_url': 'https://api.github.com/users/bherwerth/followers',
#  'following_url': 'https://api.github.com/users/bherwerth/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/bherwerth/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/bherwerth/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/bherwerth/subscriptions',
#  'organizations_url': 'https://api.github.com/users/bherwerth/orgs',
#  'repos_url': 'https://api.github.com/users/bherwerth/repos',
#  'events_url': 'https://api.github.com/users/bherwerth/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/bherwerth/received_events',
#  'type': 'User',
# ...

# %%
#reading excel file
df=pd.read_excel('D:/1.SOMALI MISHRA/1.iNeuron/Python/Data set/pandas dataset/Attribute DataSet.xlsx')

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Converting dataframe into json
#'test' is our json file name 
df.to_json('test.json')

# %%
#checking the path
#pwd:Present Working Directory
pwd
# Out:
# 'C:\\Users\\A Bhanja deo\\iNeuron\\Python class notes'

# %%
#read the same json file named as test that we have converted from excel to json
pd.read_json('C:\\Users\\A Bhanja deo\\iNeuron\\Python class notes\\test.json')
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire           None     chiffon     ruffles
# ...

# %%
#Spark Dataframe is faster than Pandas Dataframe because it uses optimizer internally.
#saving the file 
#Give the relevant path with filename if we dont want to store in present working directory
#storing as a csv file
df.to_csv("D:\\1.SOMALI MISHRA\\1.iNeuron\\Python\\Data set\\test.csv")

# %%
#storing as a csv file with delimeter as '#'
df.to_csv("D:\\1.SOMALI MISHRA\\1.iNeuron\\Python\\Data set\\test2.csv",sep='#')

# %%
#storing as a csv file with index = False(we dont want indexing while aving the file)
#default index is 'True'
df.to_csv("D:\\1.SOMALI MISHRA\\1.iNeuron\\Python\\Data set\\test3.csv",index=False)

# %%
Mysql : 
    
    1. Create a  table attribute dataset and dress dataset
    2. Do a bulk load for these two table for respective dataset 
    3. read these dataset in pandas as a dataframe 
    4. Convert attribute dataset in json format 
    5. Store this dataset into mongodb
    6. in sql task try to perform left join operation with attribute dataset and dress dataset on column Dress_ID
    7. Write a sql query to find out how many unique dress that we have based on dress id 
    8. Try to find out how mnay dress is having recommendation 0
    9. Try to find out total dress sell for individual dress id 
    10. Try to find out a third highest most selling dress id 
    
    sudhanshu@ineuron.ai
